# %%
import pandas 
import numpy 
list = []
fileInput =  pandas.read_csv('train.csv')
# print(fileInput['SalePrice'])
# Out:
# 0       208500
# 1       181500
# 2       223500
# 3       140000
# 4       250000
#          ...
# 1455    175000
# 1456    210000
# 1457    266500
# 1458    142125
# 1459    147500
# Name: SalePrice, Length: 1460, dtype: int64

# %%
y = numpy.array([fileInput['SalePrice']]).T
print(y) ; 
# x = [1,2,4] 
# print(x) ; 
# print(fileInput['SalePrice']) ;
# Out:
# [[208500]
#  [181500]
#  [223500]
#  ...
#  [266500]
#  [142125]
#  [147500]]
